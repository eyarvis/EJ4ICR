# %%
import pandas as pd

Houston = pd.read_csv("~/Desktop/Houston_1.csv", skiprows=[0])

# %%
Houston
# Out:
#      #            Category                                 Selected Variables  \
# 0    1            EJ Index                EJ Index for Particulate Matter 2.5
# 1    2            EJ Index                                 EJ Index for Ozone
# 2    3            EJ Index             EJ Index for Diesel Particulate Matter
# 3    4            EJ Index                EJ Index for Air Toxics Cancer Risk
# 4    5            EJ Index             EJ Index for Air Toxics Respiratory HI
# 5    6            EJ Index                 EJ Index for Toxic Releases to Air
# 6    7            EJ Index                     EJ Index for Traffic Proximity
# 7    8            EJ Index                            EJ Index for Lead Paint
# 8    9            EJ Index                   EJ Index for Superfund Proximity
# 9   10            EJ Index                EJ Index for RMP Facility Proximity
# 10  11            EJ Index             EJ Index for Hazardous Waste Proximity
# ...

# %%
Houston.columns
# Out:
# Index(['#', 'Category', 'Selected Variables', 'Value', 'State Avg.',
#        '%ile in State', 'USA Avg.', '%ile in USA'],
#       dtype='object')

# %%
Houston['Value']
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
# 5       NaN
# 6       NaN
# 7       NaN
# 8       NaN
# 9       NaN
# 10      NaN
# 11      NaN
# 12      NaN
# 13     10.4
# 14     69.5
# 15    0.573
# 16       40
# 17      0.4
# 18    41000
# 19      340
# 20     0.57
# 21      1.1
# 22      0.8
# 23      1.6
# 24      4.1
# 25    0.012
# 26      74%
# 27      32%
# 28      92%
# 29      57%
# 30       5%
# 31      31%
# 32      49%
# 33       4%
# 34      11%
# 35      NaN
# 36      NaN
# 37      NaN
# 38      NaN
# 39      NaN
# 40      NaN
# 41      NaN
# 42      NaN
# 43      NaN
# 44      NaN
# 45      NaN
# 46      NaN
# 47      NaN
# Name: Value, dtype: object
